# %% [markdown]
# ## 明日方舟精二Box推荐器：罗德岛之心，项目心得与经验
#
# 优先精二哪些干员，一直是困扰明日方舟萌新的一大问题。通常来说，萌新会选择在网上发帖求助，或者是在B站等平台寻找节奏榜等，以得到自己想要的答案。然而，发帖求助往往需要等待一段时间才能得到回复；而节奏榜只展现干员强度，**并不能给出精二顺序的建议**。
#
# 于是，我希望用人工智能学习经验丰富的玩家的建议，做成一个网站工具，萌新只需将自己的阵容box上传，便可以得到建议精二的干员及其精二优先度顺序。
#
# 从2020年7月13日在NGA发帖到现在，经过近半年的时间（其实中间鸽了一段时间orz……），罗德岛之心明日方舟BOX推荐器终于大功告成！下面我将分享我的经历与经验心得，希望能对各位有所帮助。
#
# ### 一、问题分析：干员Box与推荐系统
#
# 在开始之前，首先要分析Box推荐这一问题的本质。
#
# 输入是玩家的干员Box，Box由多个干员构成，输出是干员的排序。实际上，这一问题可以通过LTR算法解决。
#
# LTR，全称为Learning To Rank，顾名思义，这一种（类）学习如何排序的算法。LTR算法在我们日常生活中的应用非常广泛，其中最重要的一个应用就是推荐系统。淘宝的商品推荐，知乎、B站等平台的内容推荐等等，几乎都离不开LTR算法。
#
# 为了更好地理解LTR算法，我们以电商平台为例进行讲解。用户在搜索栏输入关键词后，会出现一系列相关商品。用户输入的关键词就是**Query**，与关键词相关的商品就是**Document**。我们希望让用户最感兴趣的商品排在前面，从而提升用户体验。LTR算法的作用就是在用户输入关键词（Query）后，对所有与关键词相关的商品（Document）进行排序，让最满足用户需求的商品尽可能地排在前面。
#
# 那么干员Box推荐与电商平台的推荐系统有什么相似之处呢？其实，**玩家上传的Box就可以看作是一个Query，Box里的干员就可以看作是Document**。我们的目标就是对Box里的所有干员进行评分，**评分越高的干员越值得优先精二**。
#
# ### 二、数据采集：小程序与云开发
#
# 在理清思路后，接下来要做的就是采集数据。首先，我们要确定采集什么样的数据——很明显，是box里每个干员的信息（干员自身属性及等级），不过还不够。我们知道监督学习需要有目标值，在box干员推荐这一问题中，目标值是干员的优先度——那么优先度该如何规定呢？
#
# 由于我准备用pair-wise的方式（后面会介绍）构建模型，因此一开始我把精二优先度划分为5个等级：最值得优先精二的干员，精二优先度较高的干员，可以延后考虑精二的干员，可选择性精二的干员以及无需精二的干员（含已精二干员）。后来在数据处理的过程中发现，由于**玩家更看重前10个以内的干员的排序结果**，因此可以延后考虑精二的干员和可选择性精二的干员这两个等级可以合并，以提高模型的精度。
#
# 此外，我把干员的等级划分成了4个等级区间，具体如下：
#
# - 0：未精一
# - 1：<=精一40级
# - 2：精一40级~精一满级
# - 3：已精二
#
# 在确定优先度的划分以及采集数据的格式后，我们罗德岛之心项目组的小伙伴们一起开发了一个用于采集数据的微信小程序，类似于抽卡模拟器（可以在微信搜索ArkHeart）。这里我们选择的是**云开发**模式，它非常适合个人以及小团队，其优点具体如下：
#
# - 基本无需后端，开发方便；
# - 云开发可以提供一个额度限定内免费的数据库，如果要采集的数据不多，平日流量不大，那么云开发绝对是不二之选。
#
# 在开发完用于采集数据的小程序后，我再次在NGA发帖，寻求经验丰富的玩家志愿者帮助采集数据。为了保证玩家给出建议的质量，我设置的要求是博士等级必须大于等于70级。最后，我们总共采集了1300多份box，数据记录在6w多条。
#
# 采集的数据格式如下：
#
# ```json
# {
# 	"_id":"1b64dd7b5f6a202f004c10b1321f4de4",
# 	"time":1600790575457,
# 	"box":[{"id":277,"name":"阿消","chs":"unchosen","class":"特种","level":0,"star":4},			{"id":187,"name":"嘉维尔","chs":"unchosen","class":"医疗","level":1,"star":4},			{"id":198,"name":"讯使","chs":"unchosen","class":"先锋","level":2,"star":4}]
# }
# ```
# ### 三、模型构建：特征工程与LGB
#
# 在采集完数据后，接下来要做的就是先确定使用什么样的模型。之前提到的LTR算法共有三大类：Pointwise类、Pairwise类以及Listwise类。Pointwise类算法把排序问题近似转换为回归问题，**只考虑单一文档，而不考虑文档之间的关系**；Pairwise类算法强调**文档顺序关系**，把排序问题近似为分类问题；而Listwise类算法则是直接优化排序列表，输入为单条样本为一个**文档排列**。
#
# 前两类算法用的比较广泛，这里我选用Pairwise类算法，构建GBRT+LR模型。这里就不展开讲原理了，有兴趣的可以自己在知乎或者csdn等平台搜一下，或是看文末的参考资料。
#
# 在训练模型之前，还有一项重要任务——**特征工程**。特征工程对于机器学习至关重要，很大程度上决定了模型的上限。
#
# **首先，我们要对数据进行清洗。** 这里一开始我犯了个大错误，对于小程序采集到的数据过于自信，觉得没有必要从头到尾对数据进行清洗。但实际上，系统采集到的数据很脏！
# 有的box因为系统bug只有一个干员被选中或者重复出现，有的box因为某些厨力玩家显得特别离谱（例如蜜蜡优先度高于塞雷娅……），还有的可能是因为侠客
# 导致某些幻神干员明明没精二却没有被选择。这些数据无疑会影响到模型的训练（实际上我在对数据完全清洗后，ndcg指标上升了5个百分点），
# 因此我们必须要进行清洗！我的做法是，把某些系统问题或者选的过于离谱的box直接删除，而剩余一些存在侠客因素或者问题不是很大的box，
# 我个人凭借着玩家经验做了些许修改。
#
# 之后，我们要确定选取哪些特征，这些特征要尽可能地与因变量有关。我们采集的数据，仅仅有干员名称、干员星级、干员等级、干员职业以及人工标注的优先度。这些特征还远远不够。**并且，我们不能把干员名称作为特征——因为明日方舟的卡池是在不断更新的。**如果把干员名称作为特征，那么每次出新干员，数据就得重新采集，模型就得重新训练，泛化能力非常差。
#
# 那么该选取什么特征呢？比较好想到的是干员的公招标签。此外，我们可以想一下我们是如何给萌新推荐干员的。
#
# **首先，我们重点关注干员的自身定位以及其强度。** 这里的干员定位我们可以用子职业来表示，比如说：技能回费先锋/杀回先锋/投锋，普通盾/奶盾等。
# 干员强度我们可以用单值离散变量来表示，0代表很弱，1代表弱，2代表强，3代表很强。
#
# **其次，我们会考虑整个Box里不同定位干员的练度比例**。
# 比如：如果萌新有一个精二的能天使，那么蓝毒、白金等五星对空狙的精二优先度就会小一些。
#
# 因此，这里我增加了子职业以及各个子职业练度比例的特征。首先子职业的划分如下：
#
# - 先锋0：挡二先锋0，杀回先锋1，投锋2
# - 近卫1：挡一近卫3，挡二近卫4，群卫5，远卫6
# - 狙击2：快狙7，群狙8，超远狙9，特殊狙10
# - 重装3：盾11
# - 医疗4：群奶12，单奶13
# - 辅助5：减速14，召唤15
# - 术士6：单法16，群法17
# - 特种7：快活18，推拉19
# - 单独的特殊类：20
#
# 有人可能会问：你这分的不对啊？近卫里面还有法伤近卫，盾里面还有奶盾，你这分的不够细啊。实际上，子职业并不是分的越细越好，如果分的过细，那么很容易出现类别之间的样本数量过于失衡的情况，影响模型的精度。比方说，奶盾与普通盾，其实可以靠“治疗”标签区分，因此无需过于细分子职业类别。
#
# 那么怎么确定分的好不好呢？一方面我们可以看评价模型的指标——NDCG的大小。NDCG介于0~1之间，越接近于1，说明模型分类越精确。
# 除了NDCG之外，还有NDCG@k，k是人为设定的整数值。这两者分别有什么含义呢？
# 简单讲，NDCG和NDCG@k都是评判一个模型排序正确程度的指标，**区别在于，
# NDCG看的是所有item也就是doc的排序正确程度，而NDCG@k只关心排名前k个文档
# 的排序正确程度。**
# 这里我遇到了一个坑。一开始，我想当然地以为，由于玩家重点关注前10个
# 干员的排序，因此优化指标就设为NDCG@10。然而，这样训练出来的模型，
# 虽说在预测6星干员方面效果很不错，但对于某些好用低星干员，以及已有同类高练
# 干员无需再练同类干员的情况下，效果不是很理想。原因在于：优先度为4，3
# 的干员在前10位占据了绝大多数位置，然而在整个box中，优先度为2，1的干员
# 才是多数。NDCG@k的k设的过于靠前，会让一些强力干员的优先度过高，以至于
# 在某些特殊场合下（例如拥有精二蓝毒和一个精一40级白金）下，本应是某些较为适合box但本身
# 强度不是特别高的干员的优先度较低，而让一些强度较高但已有同类替代的干员
# 优先度较高。因此，NDCG@k中的k不可以过小。最后我选取了NDCG@30，效果
# 较为理想。
#
# 另一方面，我们可以看特征重要度。在训练完树模型后，我们可以查看模型里各个特征的重要性——某个特征的重要性越高，就说明该特征在模型训练中发挥了越重要的作用，反之亦然。
#
# 经过反复尝试，我选取了上述的干员子职业分类方式，并去除了群攻、位移、费用回复、支援机械、快速复活、召唤等标签。
#
# 此外，干员子职业练度比例的计算公式如下：

# %%
$$
某子职业练度比例=\frac{\sum (干员强度/3)*(属于该子职业干员等级区间/3)}{所有子职业练度和}
$$

# %% [markdown]
# 同一Box下的干员共享子职业练度比例的特征。
#
# ### 四、代码讲解
#
# GBRT+LR的pairwise类算法，我们可以用LGB去做。这里必须吹一下LGB，又快又准！
#
# 下面开始详细讲解一下代码（部分代码参考了https://github.com/jiangnanboy/learning_to_rank）。
# 首先，我们需要加载已经处理过的表格数据：

# %%
import pandas as pd
import numpy as np

np.random.seed(233) # 设置种子
df = pd.read_excel('./data.xlsx')
print(df)
# Out:
#         qid  star  level  class  subclass  power  是否具有治疗  是否具有支援  是否具有输出  \
# 0         0     4      2      0         2      2       1       0       0
# 1         0     6      1      6        16      3       0       0       1
# 2         0     6      2      5        14      3       0       1       0
# 3         0     5      2      0         2      2       0       1       0
# 4         0     6      1      1         4      3       0       0       1
# 5         0     5      1      1         5      2       0       0       0
# 6         0     5      0      1         6      2       0       0       1
# 7         0     4      2      0         1      1       0       0       1
# 8         0     5      1      6        20      1       0       0       0
# 9         0     5      1      3        11      1       0       0       1
# 10        0     4      1      7        20      1       0       0       1
# 11        0     4      1      2         8      1       0       0       0
# 12        0     5      1      6        16      2       0       0       1
# 13        0     4      0      1         3      0       0       0       1
# 14        0     4      0      3        11      1       0       0       0
# 15        0     4      0      3        11      1       1       0       0
# 16        0     4      0      2         9      0       0       0       1
# 17        0     4      0      7        18      1       0       0       1
# 18        0     4      3      7        19      0       0       0       0
# 19        0     5      2      2         8      0       0       0       0
# 20        0     4      2      1         3      0       0       0       1
# 21        0     4      2      5        15      0       0       0       0
# 22        0     4      2      1         3      0       0       0       1
# 23        0     4      2      1         5      0       0       0       0
# 24        0     4      2      3        11      0       0       0       0
# 25        0     4      2      4        13      1       1       0       0
# 26        0     4      2      7        19      0       0       0       0
# 27        0     6      1      7        20      1       0       1       1
# 28        0     5      1      1         6      1       0       0       1
# 29        0     5      1      1         5      1       0       0       0
# ...     ...   ...    ...    ...       ...    ...     ...     ...     ...
# 62521  1287     4      1      0         0      0       0       0       0
# 62522  1287     4      1      2         8      1       0       0       0
# 62523  1287     4      1      3        11      1       0       0       0
# 62524  1287     5      1      3        11      1       0       0       1
# 62525  1287     5      1      1         3      0       0       0       1
# 62526  1287     4      0      7        19      0       0       0       0
# 62527  1287     4      0      6        17      1       0       0       0
# 62528  1287     4      0      2         7      1       0       0       1
# 62529  1287     4      0      0         0      0       0       0       1
# 62530  1287     4      0      7        18      0       0       0       0
# 62531  1287     4      0      3        11      0       0       0       0
# 62532  1287     4      0      7        18      1       0       0       1
# 62533  1287     4      0      5        14      1       1       0       0
# 62534  1287     4      0      1         3      0       0       0       1
# 62535  1287     4      0      2        10      0       0       0       1
# 62536  1287     4      0      7        20      1       0       0       1
# 62537  1287     4      3      4        13      2       1       0       0
# 62538  1287     5      3      2         8      2       0       0       0
# 62539  1287     4      2      4        13      1       1       0       0
# 62540  1287     4      1      5        15      0       0       0       0
# 62541  1287     4      1      7        19      0       0       0       0
# 62542  1287     5      1      2         8      0       0       0       0
# 62543  1287     4      0      1         4      0       0       1       1
# 62544  1287     4      0      1         3      0       0       0       1
# 62545  1287     4      0      2         7      0       0       0       1
# 62546  1287     4      0      6        17      0       0       0       0
# 62547  1287     4      0      5        14      0       0       0       0
# 62548  1287     4      0      2         9      0       0       0       1
# 62549  1287     4      0      4        12      2       1       0       0
# 62550  1287     4      0      3        11      0       0       0       1
#
#        是否具有减速 ...     群奶练度比例    单奶练度比例    减速练度比例  召唤练度比例    单法练度比例    群法练度比例  \
# 0           0 ...   0.000000  0.108696  0.130435     0.0  0.130435  0.065217
# 1           0 ...   0.000000  0.108696  0.130435     0.0  0.130435  0.065217
# 2           1 ...   0.000000  0.108696  0.130435     0.0  0.130435  0.065217
# 3           0 ...   0.000000  0.108696  0.130435     0.0  0.130435  0.065217
# 4           0 ...   0.000000  0.108696  0.130435     0.0  0.130435  0.065217
# 5           0 ...   0.000000  0.108696  0.130435     0.0  0.130435  0.065217
# 6           0 ...   0.000000  0.108696  0.130435     0.0  0.130435  0.065217
# 7           0 ...   0.000000  0.108696  0.130435     0.0  0.130435  0.065217
# 8           0 ...   0.000000  0.108696  0.130435     0.0  0.130435  0.065217
# 9           0 ...   0.000000  0.108696  0.130435     0.0  0.130435  0.065217
# 10          0 ...   0.000000  0.108696  0.130435     0.0  0.130435  0.065217
# 11          1 ...   0.000000  0.108696  0.130435     0.0  0.130435  0.065217
# 12          0 ...   0.000000  0.108696  0.130435     0.0  0.130435  0.065217
# 13          0 ...   0.000000  0.108696  0.130435     0.0  0.130435  0.065217
# 14          0 ...   0.000000  0.108696  0.130435     0.0  0.130435  0.065217
# 15          0 ...   0.000000  0.108696  0.130435     0.0  0.130435  0.065217
# 16          1 ...   0.000000  0.108696  0.130435     0.0  0.130435  0.065217
# 17          0 ...   0.000000  0.108696  0.130435     0.0  0.130435  0.065217
# 18          0 ...   0.000000  0.108696  0.130435     0.0  0.130435  0.065217
# 19          0 ...   0.000000  0.108696  0.130435     0.0  0.130435  0.065217
# 20          0 ...   0.000000  0.108696  0.130435     0.0  0.130435  0.065217
# 21          0 ...   0.000000  0.108696  0.130435     0.0  0.130435  0.065217
# 22          0 ...   0.000000  0.108696  0.130435     0.0  0.130435  0.065217
# 23          0 ...   0.000000  0.108696  0.130435     0.0  0.130435  0.065217
# 24          0 ...   0.000000  0.108696  0.130435     0.0  0.130435  0.065217
# 25          0 ...   0.000000  0.108696  0.130435     0.0  0.130435  0.065217
# 26          0 ...   0.000000  0.108696  0.130435     0.0  0.130435  0.065217
# 27          0 ...   0.000000  0.108696  0.130435     0.0  0.130435  0.065217
# 28          0 ...   0.000000  0.108696  0.130435     0.0  0.130435  0.065217
# 29          0 ...   0.000000  0.108696  0.130435     0.0  0.130435  0.065217
# ...       ... ...        ...       ...       ...     ...       ...       ...
# 62521       0 ...   0.041667  0.166667  0.000000     0.0  0.083333  0.000000
# 62522       1 ...   0.041667  0.166667  0.000000     0.0  0.083333  0.000000
# 62523       0 ...   0.041667  0.166667  0.000000     0.0  0.083333  0.000000
# 62524       0 ...   0.041667  0.166667  0.000000     0.0  0.083333  0.000000
# 62525       0 ...   0.041667  0.166667  0.000000     0.0  0.083333  0.000000
# 62526       0 ...   0.041667  0.166667  0.000000     0.0  0.083333  0.000000
# 62527       0 ...   0.041667  0.166667  0.000000     0.0  0.083333  0.000000
# 62528       1 ...   0.041667  0.166667  0.000000     0.0  0.083333  0.000000
# 62529       0 ...   0.041667  0.166667  0.000000     0.0  0.083333  0.000000
# 62530       0 ...   0.041667  0.166667  0.000000     0.0  0.083333  0.000000
# 62531       0 ...   0.041667  0.166667  0.000000     0.0  0.083333  0.000000
# 62532       0 ...   0.041667  0.166667  0.000000     0.0  0.083333  0.000000
# 62533       1 ...   0.041667  0.166667  0.000000     0.0  0.083333  0.000000
# 62534       0 ...   0.041667  0.166667  0.000000     0.0  0.083333  0.000000
# 62535       0 ...   0.041667  0.166667  0.000000     0.0  0.083333  0.000000
# 62536       0 ...   0.041667  0.166667  0.000000     0.0  0.083333  0.000000
# 62537       0 ...   0.041667  0.166667  0.000000     0.0  0.083333  0.000000
# 62538       0 ...   0.041667  0.166667  0.000000     0.0  0.083333  0.000000
# 62539       0 ...   0.041667  0.166667  0.000000     0.0  0.083333  0.000000
# 62540       0 ...   0.041667  0.166667  0.000000     0.0  0.083333  0.000000
# 62541       0 ...   0.041667  0.166667  0.000000     0.0  0.083333  0.000000
# 62542       0 ...   0.041667  0.166667  0.000000     0.0  0.083333  0.000000
# 62543       0 ...   0.041667  0.166667  0.000000     0.0  0.083333  0.000000
# 62544       0 ...   0.041667  0.166667  0.000000     0.0  0.083333  0.000000
# 62545       0 ...   0.041667  0.166667  0.000000     0.0  0.083333  0.000000
# 62546       1 ...   0.041667  0.166667  0.000000     0.0  0.083333  0.000000
# 62547       1 ...   0.041667  0.166667  0.000000     0.0  0.083333  0.000000
# 62548       1 ...   0.041667  0.166667  0.000000     0.0  0.083333  0.000000
# 62549       0 ...   0.041667  0.166667  0.000000     0.0  0.083333  0.000000
# 62550       0 ...   0.041667  0.166667  0.000000     0.0  0.083333  0.000000
#
#          快活练度比例    推拉练度比例  特殊干员练度比例  chs
# 0      0.000000  0.021739  0.086957    4
# 1      0.000000  0.021739  0.086957    4
# 2      0.000000  0.021739  0.086957    3
# 3      0.000000  0.021739  0.086957    3
# 4      0.000000  0.021739  0.086957    3
# 5      0.000000  0.021739  0.086957    3
# 6      0.000000  0.021739  0.086957    3
# 7      0.000000  0.021739  0.086957    2
# 8      0.000000  0.021739  0.086957    2
# 9      0.000000  0.021739  0.086957    2
# 10     0.000000  0.021739  0.086957    2
# 11     0.000000  0.021739  0.086957    2
# 12     0.000000  0.021739  0.086957    2
# 13     0.000000  0.021739  0.086957    2
# 14     0.000000  0.021739  0.086957    2
# 15     0.000000  0.021739  0.086957    2
# 16     0.000000  0.021739  0.086957    2
# 17     0.000000  0.021739  0.086957    2
# 18     0.000000  0.021739  0.086957    1
# 19     0.000000  0.021739  0.086957    1
# 20     0.000000  0.021739  0.086957    1
# 21     0.000000  0.021739  0.086957    1
# 22     0.000000  0.021739  0.086957    1
# 23     0.000000  0.021739  0.086957    1
# 24     0.000000  0.021739  0.086957    1
# 25     0.000000  0.021739  0.086957    1
# 26     0.000000  0.021739  0.086957    1
# 27     0.000000  0.021739  0.086957    1
# 28     0.000000  0.021739  0.086957    1
# 29     0.000000  0.021739  0.086957    1
# ...         ...       ...       ...  ...
# 62521  0.083333  0.020833  0.000000    2
# 62522  0.083333  0.020833  0.000000    2
# 62523  0.083333  0.020833  0.000000    2
# 62524  0.083333  0.020833  0.000000    2
# 62525  0.083333  0.020833  0.000000    2
# 62526  0.083333  0.020833  0.000000    2
# 62527  0.083333  0.020833  0.000000    2
# 62528  0.083333  0.020833  0.000000    2
# 62529  0.083333  0.020833  0.000000    2
# 62530  0.083333  0.020833  0.000000    2
# 62531  0.083333  0.020833  0.000000    2
# 62532  0.083333  0.020833  0.000000    2
# 62533  0.083333  0.020833  0.000000    2
# 62534  0.083333  0.020833  0.000000    2
# 62535  0.083333  0.020833  0.000000    2
# 62536  0.083333  0.020833  0.000000    2
# 62537  0.083333  0.020833  0.000000    1
# 62538  0.083333  0.020833  0.000000    1
# 62539  0.083333  0.020833  0.000000    1
# 62540  0.083333  0.020833  0.000000    1
# 62541  0.083333  0.020833  0.000000    1
# 62542  0.083333  0.020833  0.000000    1
# 62543  0.083333  0.020833  0.000000    1
# 62544  0.083333  0.020833  0.000000    1
# 62545  0.083333  0.020833  0.000000    1
# 62546  0.083333  0.020833  0.000000    1
# 62547  0.083333  0.020833  0.000000    1
# 62548  0.083333  0.020833  0.000000    1
# 62549  0.083333  0.020833  0.000000    1
# 62550  0.083333  0.020833  0.000000    1
#
# [62551 rows x 37 columns]

# %% [markdown]
# 接下来，我们需要把整个数据集划分为训练集、验证集和测试集。这里的比例约为7：2：1。

# %%
def qid(id):
    """
    输入表格数据的qid（query id）列，转换为符合lgb模型的格式
    """
    num = id[0]
    counts = 0
    group_ids = []
    for new_num in id:
        if new_num == num:
            counts +=1
        else:
            num = new_num
            group_ids.append(counts)
            counts = 1
    group_ids.append(counts)
    return group_ids


qid_set = set(df['qid']) # 获取qid（query id）集合
qid_li = list(qid_set)
test_size = int(len(qid_li)*0.1) # 获得测试集大小

# 筛除掉精二干员，精二干员不参与模型训练
level_li = [0,1,2]
df = df[df['level'].isin(level_li)]

# 数据集划分，X代表输入的特征，y代表目标值（相关度）
test_li = np.random.choice(qid_li,size=test_size,replace=False)
test_set = set(test_li)

train_set = qid_set.difference(test_set)
train_li = list(train_set)

val_size = int(len(train_li)*0.2)
val_li = np.random.choice(train_li,size=val_size,replace=False)
val_set = set(val_li)

train_set = train_set.difference(val_set)
train_li = list(train_set)

train_data = df[df['qid'].isin(train_li)]
val_data = df[df['qid'].isin(val_li)]
test_data = df[df['qid'].isin(test_li)]

data = train_data.values
len_v = len(data[0])
train_y = data[:,-1]
train_X = data[:,1:len_v-1]
train_qid = data[:,0]
train_qid = train_qid.astype(int)
train_qid = qid(train_qid)
train_y = train_y.astype(int)

data2 = test_data.values
len_v = len(data2[0])
test_y = data2[:,-1]
test_X = data2[:,1:len_v-1]
test_qid = data2[:,0]
test_qid = test_qid.astype(int)
test_y = test_y.astype(int)

data3 = val_data.values
len_v = len(data3[0])
val_y = data3[:,-1]
val_X = data3[:,1:len_v-1]
val_qid = data3[:,0]
val_qid = val_qid.astype(int)
val_qid = qid(val_qid)
val_y = val_y.astype(int)

# %% [markdown]
# 之后我们把训练集和验证集的数据加载为LGB的格式。

# %%
import lightgbm as lgb
train_data = lgb.Dataset(train_X, label=train_y, group=train_qid,feature_name=['star','level','class','subclass','power',
            '是否具有治疗','是否具有支援','是否具有输出',
            '是否具有减速','是否具有生存','是否具有防护','是否具有削弱',
            '是否具有控场','是否具有爆发',
            '挡二先锋练度比例','杀回先锋练度比例','投锋练度比例',
            '挡一近卫练度比例','挡二近卫练度比例','群体近卫练度比例',
            '远卫练度比例','快狙练度比例','群狙练度比例','超远狙练度比例',
            '特殊狙练度比例','盾练度比例','群奶练度比例','单奶练度比例',
            '减速练度比例','召唤练度比例','单法练度比例',
            '群法练度比例','快活练度比例','推拉练度比例','特殊干员练度比例'],
                         categorical_feature=['star','level','class','subclass','power'])

val_data = lgb.Dataset(val_X, label=val_y, group=val_qid,feature_name=['star','level','class','subclass','power',
            '是否具有治疗','是否具有支援','是否具有输出',
            '是否具有减速','是否具有生存','是否具有防护','是否具有削弱',
            '是否具有控场','是否具有爆发',
            '挡二先锋练度比例','杀回先锋练度比例','投锋练度比例',
            '挡一近卫练度比例','挡二近卫练度比例','群体近卫练度比例',
            '远卫练度比例','快狙练度比例','群狙练度比例','超远狙练度比例',
            '特殊狙练度比例','盾练度比例','群奶练度比例','单奶练度比例',
            '减速练度比例','召唤练度比例','单法练度比例',
            '群法练度比例','快活练度比例','推拉练度比例','特殊干员练度比例'],
                         categorical_feature=['star','level','class','subclass','power'])

# %% [markdown]
# 之后设置参数，进行训练，并保存模型。

# %%
#参数已经调过参
params = {
    'task': 'train',  # 执行的任务类型
    'boosting_type': 'gbrt',  # 基学习器
    'objective': 'lambdarank',  # 排序任务(目标函数)
    'metric': 'ndcg',  # 度量的指标(评估函数)
    'metric_freq': 1,  # 每隔多少次输出一次度量结果
    'train_metric': True,  # 训练时就输出度量结果
    'ndcg_at': [30],# 设ndcg@30用于优化模型
    'max_bin': 255,  # 一个整数，表示最大的桶的数量。默认值为 255。lightgbm 会根据它来自动压缩内存。如max_bin=255 时，则lightgbm 将使用uint8 来表示特征的每一个值。
    'num_iterations': 400,  # 迭代次数，即生成的树的棵数
    'learning_rate': 0.05,  # 学习率
    'num_leaves': 45,  # 叶子数
    'tree_learner': 'serial',  # 用于并行学习，‘serial’： 单台机器的tree learner
    'nthread': 12, # 线程数
    'min_data_in_leaf': 1,  # 一个叶子节点上包含的最少样本数量
    'feature_fraction': 0.7, # 每次迭代中随机选择70%的参数来建树，用于抑制过拟合
    'bagging_fraction': 0.65, # 每次迭代时用的数据比例，用于抑制过拟合
    'bagging_freq' : 4, # 意味着每 7 次迭代执行bagging
    'verbose': 2  # 显示训练时的信息
}
gbm = lgb.train(params, train_data, valid_sets=[val_data],feature_name=['star','level','class','subclass','power',
            '是否具有治疗','是否具有支援','是否具有输出',
            '是否具有减速','是否具有生存','是否具有防护','是否具有削弱',
            '是否具有控场','是否具有爆发',
            '挡二先锋练度比例','杀回先锋练度比例','投锋练度比例',
            '挡一近卫练度比例','挡二近卫练度比例','群体近卫练度比例',
            '远卫练度比例','快狙练度比例','群狙练度比例','超远狙练度比例',
            '特殊狙练度比例','盾练度比例','群奶练度比例','单奶练度比例',
            '减速练度比例','召唤练度比例','单法练度比例',
            '群法练度比例','快活练度比例','推拉练度比例','特殊干员练度比例'],
                         categorical_feature=['star','level','class','subclass','power'])

gbm.save_model('./model/model.txt')
# Out:
# E:\anaconda\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# E:\anaconda\lib\site-packages\lightgbm\basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# E:\anaconda\lib\site-packages\lightgbm\basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Debug] Dataset::GetMultiBinFromSparseFeatures: sparse rate 0.844945
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.460090
# [LightGBM] [Debug] init for col-wise cost 0.003744 seconds, init for row-wise cost 0.010853 seconds
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.012352 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4155
# [LightGBM] [Info] Number of data points in the train set: 43126, number of used features: 35
# [LightGBM] [Debug] Use subset for bagging
# [LightGBM] [Debug] Re-bagging, using 28064 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [1]	valid_0's ndcg@30: 0.9326
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [2]	valid_0's ndcg@30: 0.938146
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [3]	valid_0's ndcg@30: 0.939649
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 9
# [4]	valid_0's ndcg@30: 0.940074
# [LightGBM] [Debug] Re-bagging, using 28038 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [5]	valid_0's ndcg@30: 0.943702
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [6]	valid_0's ndcg@30: 0.94592
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [7]	valid_0's ndcg@30: 0.942825
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [8]	valid_0's ndcg@30: 0.942826
# [LightGBM] [Debug] Re-bagging, using 28155 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [9]	valid_0's ndcg@30: 0.944604
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 9
# [10]	valid_0's ndcg@30: 0.945333
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [11]	valid_0's ndcg@30: 0.946582
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [12]	valid_0's ndcg@30: 0.947719
# [LightGBM] [Debug] Re-bagging, using 28048 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [13]	valid_0's ndcg@30: 0.946714
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [14]	valid_0's ndcg@30: 0.9467
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [15]	valid_0's ndcg@30: 0.946052
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [16]	valid_0's ndcg@30: 0.946128
# [LightGBM] [Debug] Re-bagging, using 27874 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 14
# [17]	valid_0's ndcg@30: 0.946657
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 9
# [18]	valid_0's ndcg@30: 0.946392
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [19]	valid_0's ndcg@30: 0.946593
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [20]	valid_0's ndcg@30: 0.947137
# [LightGBM] [Debug] Re-bagging, using 28239 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [21]	valid_0's ndcg@30: 0.947732
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 9
# [22]	valid_0's ndcg@30: 0.946266
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 9
# [23]	valid_0's ndcg@30: 0.946142
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [24]	valid_0's ndcg@30: 0.946309
# [LightGBM] [Debug] Re-bagging, using 27882 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [25]	valid_0's ndcg@30: 0.947622
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [26]	valid_0's ndcg@30: 0.947799
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [27]	valid_0's ndcg@30: 0.947679
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [28]	valid_0's ndcg@30: 0.948263
# [LightGBM] [Debug] Re-bagging, using 28052 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [29]	valid_0's ndcg@30: 0.948412
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [30]	valid_0's ndcg@30: 0.949305
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [31]	valid_0's ndcg@30: 0.949192
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [32]	valid_0's ndcg@30: 0.948802
# [LightGBM] [Debug] Re-bagging, using 28262 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [33]	valid_0's ndcg@30: 0.948575
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [34]	valid_0's ndcg@30: 0.949141
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 16
# [35]	valid_0's ndcg@30: 0.949396
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [36]	valid_0's ndcg@30: 0.949039
# [LightGBM] [Debug] Re-bagging, using 27985 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [37]	valid_0's ndcg@30: 0.949127
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [38]	valid_0's ndcg@30: 0.948408
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [39]	valid_0's ndcg@30: 0.94851
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 14
# [40]	valid_0's ndcg@30: 0.948431
# [LightGBM] [Debug] Re-bagging, using 28045 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [41]	valid_0's ndcg@30: 0.949696
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 9
# [42]	valid_0's ndcg@30: 0.948276
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [43]	valid_0's ndcg@30: 0.948417
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 9
# [44]	valid_0's ndcg@30: 0.948724
# [LightGBM] [Debug] Re-bagging, using 28020 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 9
# [45]	valid_0's ndcg@30: 0.948759
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 9
# [46]	valid_0's ndcg@30: 0.948671
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [47]	valid_0's ndcg@30: 0.949404
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [48]	valid_0's ndcg@30: 0.949727
# [LightGBM] [Debug] Re-bagging, using 27983 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 15
# [49]	valid_0's ndcg@30: 0.948934
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [50]	valid_0's ndcg@30: 0.948751
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [51]	valid_0's ndcg@30: 0.948961
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [52]	valid_0's ndcg@30: 0.949373
# [LightGBM] [Debug] Re-bagging, using 27939 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 15
# [53]	valid_0's ndcg@30: 0.949381
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [54]	valid_0's ndcg@30: 0.949387
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [55]	valid_0's ndcg@30: 0.949458
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [56]	valid_0's ndcg@30: 0.950097
# [LightGBM] [Debug] Re-bagging, using 28015 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 9
# [57]	valid_0's ndcg@30: 0.949581
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [58]	valid_0's ndcg@30: 0.949951
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [59]	valid_0's ndcg@30: 0.94969
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [60]	valid_0's ndcg@30: 0.949963
# [LightGBM] [Debug] Re-bagging, using 28099 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [61]	valid_0's ndcg@30: 0.950534
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [62]	valid_0's ndcg@30: 0.950269
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [63]	valid_0's ndcg@30: 0.950115
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 9
# [64]	valid_0's ndcg@30: 0.950326
# [LightGBM] [Debug] Re-bagging, using 27946 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [65]	valid_0's ndcg@30: 0.950637
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 8
# [66]	valid_0's ndcg@30: 0.950658
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 9
# [67]	valid_0's ndcg@30: 0.950507
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 9
# [68]	valid_0's ndcg@30: 0.950648
# [LightGBM] [Debug] Re-bagging, using 28089 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [69]	valid_0's ndcg@30: 0.950453
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [70]	valid_0's ndcg@30: 0.950076
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [71]	valid_0's ndcg@30: 0.95021
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 9
# [72]	valid_0's ndcg@30: 0.950405
# [LightGBM] [Debug] Re-bagging, using 28188 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [73]	valid_0's ndcg@30: 0.950518
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [74]	valid_0's ndcg@30: 0.950505
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 9
# [75]	valid_0's ndcg@30: 0.950455
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 14
# [76]	valid_0's ndcg@30: 0.951441
# [LightGBM] [Debug] Re-bagging, using 27941 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [77]	valid_0's ndcg@30: 0.951344
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [78]	valid_0's ndcg@30: 0.951208
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [79]	valid_0's ndcg@30: 0.951301
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 9
# [80]	valid_0's ndcg@30: 0.951576
# [LightGBM] [Debug] Re-bagging, using 28097 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [81]	valid_0's ndcg@30: 0.951626
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 15
# [82]	valid_0's ndcg@30: 0.951728
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [83]	valid_0's ndcg@30: 0.951149
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [84]	valid_0's ndcg@30: 0.951089
# [LightGBM] [Debug] Re-bagging, using 27980 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [85]	valid_0's ndcg@30: 0.949894
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [86]	valid_0's ndcg@30: 0.949785
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [87]	valid_0's ndcg@30: 0.949829
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [88]	valid_0's ndcg@30: 0.950074
# [LightGBM] [Debug] Re-bagging, using 28000 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [89]	valid_0's ndcg@30: 0.949703
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [90]	valid_0's ndcg@30: 0.95101
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [91]	valid_0's ndcg@30: 0.950069
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [92]	valid_0's ndcg@30: 0.950152
# [LightGBM] [Debug] Re-bagging, using 27968 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [93]	valid_0's ndcg@30: 0.950204
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [94]	valid_0's ndcg@30: 0.949894
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [95]	valid_0's ndcg@30: 0.949786
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [96]	valid_0's ndcg@30: 0.949893
# [LightGBM] [Debug] Re-bagging, using 28202 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [97]	valid_0's ndcg@30: 0.949635
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [98]	valid_0's ndcg@30: 0.949877
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 9
# [99]	valid_0's ndcg@30: 0.950663
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [100]	valid_0's ndcg@30: 0.949682
# [LightGBM] [Debug] Re-bagging, using 28101 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [101]	valid_0's ndcg@30: 0.950107
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [102]	valid_0's ndcg@30: 0.949988
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 9
# [103]	valid_0's ndcg@30: 0.950122
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [104]	valid_0's ndcg@30: 0.950556
# [LightGBM] [Debug] Re-bagging, using 28004 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [105]	valid_0's ndcg@30: 0.950615
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [106]	valid_0's ndcg@30: 0.950163
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [107]	valid_0's ndcg@30: 0.951451
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [108]	valid_0's ndcg@30: 0.951572
# [LightGBM] [Debug] Re-bagging, using 27947 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [109]	valid_0's ndcg@30: 0.951166
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 9
# [110]	valid_0's ndcg@30: 0.95117
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 9
# [111]	valid_0's ndcg@30: 0.951358
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [112]	valid_0's ndcg@30: 0.951194
# [LightGBM] [Debug] Re-bagging, using 28013 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 15
# [113]	valid_0's ndcg@30: 0.951009
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [114]	valid_0's ndcg@30: 0.950836
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [115]	valid_0's ndcg@30: 0.951214
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [116]	valid_0's ndcg@30: 0.951044
# [LightGBM] [Debug] Re-bagging, using 27699 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [117]	valid_0's ndcg@30: 0.951042
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [118]	valid_0's ndcg@30: 0.951138
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [119]	valid_0's ndcg@30: 0.950686
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [120]	valid_0's ndcg@30: 0.950984
# [LightGBM] [Debug] Re-bagging, using 27987 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [121]	valid_0's ndcg@30: 0.951215
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [122]	valid_0's ndcg@30: 0.951468
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [123]	valid_0's ndcg@30: 0.951567
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [124]	valid_0's ndcg@30: 0.951668
# [LightGBM] [Debug] Re-bagging, using 27972 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [125]	valid_0's ndcg@30: 0.951622
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [126]	valid_0's ndcg@30: 0.951331
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [127]	valid_0's ndcg@30: 0.95135
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [128]	valid_0's ndcg@30: 0.951156
# [LightGBM] [Debug] Re-bagging, using 27929 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [129]	valid_0's ndcg@30: 0.950543
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [130]	valid_0's ndcg@30: 0.950547
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [131]	valid_0's ndcg@30: 0.950457
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [132]	valid_0's ndcg@30: 0.950528
# [LightGBM] [Debug] Re-bagging, using 28147 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [133]	valid_0's ndcg@30: 0.950439
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [134]	valid_0's ndcg@30: 0.950363
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 15
# [135]	valid_0's ndcg@30: 0.950458
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [136]	valid_0's ndcg@30: 0.950567
# [LightGBM] [Debug] Re-bagging, using 28062 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [137]	valid_0's ndcg@30: 0.950398
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [138]	valid_0's ndcg@30: 0.950386
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [139]	valid_0's ndcg@30: 0.95041
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [140]	valid_0's ndcg@30: 0.950448
# [LightGBM] [Debug] Re-bagging, using 28190 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [141]	valid_0's ndcg@30: 0.9504
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [142]	valid_0's ndcg@30: 0.950337
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [143]	valid_0's ndcg@30: 0.950256
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [144]	valid_0's ndcg@30: 0.950183
# [LightGBM] [Debug] Re-bagging, using 28119 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 17
# [145]	valid_0's ndcg@30: 0.949809
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [146]	valid_0's ndcg@30: 0.949868
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 15
# [147]	valid_0's ndcg@30: 0.950019
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [148]	valid_0's ndcg@30: 0.949934
# [LightGBM] [Debug] Re-bagging, using 28002 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [149]	valid_0's ndcg@30: 0.949852
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [150]	valid_0's ndcg@30: 0.94983
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 18
# [151]	valid_0's ndcg@30: 0.949812
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [152]	valid_0's ndcg@30: 0.9506
# [LightGBM] [Debug] Re-bagging, using 27928 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [153]	valid_0's ndcg@30: 0.950694
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [154]	valid_0's ndcg@30: 0.950936
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [155]	valid_0's ndcg@30: 0.951301
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [156]	valid_0's ndcg@30: 0.95097
# [LightGBM] [Debug] Re-bagging, using 28079 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [157]	valid_0's ndcg@30: 0.950855
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [158]	valid_0's ndcg@30: 0.951002
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 16
# [159]	valid_0's ndcg@30: 0.950858
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [160]	valid_0's ndcg@30: 0.950869
# [LightGBM] [Debug] Re-bagging, using 27991 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [161]	valid_0's ndcg@30: 0.951105
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [162]	valid_0's ndcg@30: 0.95088
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [163]	valid_0's ndcg@30: 0.951167
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [164]	valid_0's ndcg@30: 0.95115
# [LightGBM] [Debug] Re-bagging, using 28158 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [165]	valid_0's ndcg@30: 0.950706
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [166]	valid_0's ndcg@30: 0.950767
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 14
# [167]	valid_0's ndcg@30: 0.950547
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [168]	valid_0's ndcg@30: 0.950408
# [LightGBM] [Debug] Re-bagging, using 28007 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [169]	valid_0's ndcg@30: 0.950363
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [170]	valid_0's ndcg@30: 0.950185
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 14
# [171]	valid_0's ndcg@30: 0.950568
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [172]	valid_0's ndcg@30: 0.950937
# [LightGBM] [Debug] Re-bagging, using 28009 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [173]	valid_0's ndcg@30: 0.950536
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 15
# [174]	valid_0's ndcg@30: 0.950081
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 14
# [175]	valid_0's ndcg@30: 0.950035
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 15
# [176]	valid_0's ndcg@30: 0.949906
# [LightGBM] [Debug] Re-bagging, using 28203 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [177]	valid_0's ndcg@30: 0.94983
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 14
# [178]	valid_0's ndcg@30: 0.94982
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [179]	valid_0's ndcg@30: 0.949937
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [180]	valid_0's ndcg@30: 0.950064
# [LightGBM] [Debug] Re-bagging, using 28082 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [181]	valid_0's ndcg@30: 0.95015
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [182]	valid_0's ndcg@30: 0.950338
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 14
# [183]	valid_0's ndcg@30: 0.950024
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 9
# [184]	valid_0's ndcg@30: 0.950198
# [LightGBM] [Debug] Re-bagging, using 27812 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [185]	valid_0's ndcg@30: 0.950177
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [186]	valid_0's ndcg@30: 0.950253
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [187]	valid_0's ndcg@30: 0.950111
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 14
# [188]	valid_0's ndcg@30: 0.950316
# [LightGBM] [Debug] Re-bagging, using 27874 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [189]	valid_0's ndcg@30: 0.950285
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [190]	valid_0's ndcg@30: 0.950244
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 16
# [191]	valid_0's ndcg@30: 0.950253
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [192]	valid_0's ndcg@30: 0.950129
# [LightGBM] [Debug] Re-bagging, using 28151 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [193]	valid_0's ndcg@30: 0.950157
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [194]	valid_0's ndcg@30: 0.949877
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 14
# [195]	valid_0's ndcg@30: 0.949964
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 14
# [196]	valid_0's ndcg@30: 0.949846
# [LightGBM] [Debug] Re-bagging, using 27910 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 15
# [197]	valid_0's ndcg@30: 0.949906
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [198]	valid_0's ndcg@30: 0.949747
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [199]	valid_0's ndcg@30: 0.950171
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [200]	valid_0's ndcg@30: 0.950187
# [LightGBM] [Debug] Re-bagging, using 28115 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [201]	valid_0's ndcg@30: 0.949924
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [202]	valid_0's ndcg@30: 0.950066
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 9
# [203]	valid_0's ndcg@30: 0.95011
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [204]	valid_0's ndcg@30: 0.950164
# [LightGBM] [Debug] Re-bagging, using 28127 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [205]	valid_0's ndcg@30: 0.950196
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [206]	valid_0's ndcg@30: 0.950146
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 14
# [207]	valid_0's ndcg@30: 0.950227
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [208]	valid_0's ndcg@30: 0.95025
# [LightGBM] [Debug] Re-bagging, using 28062 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [209]	valid_0's ndcg@30: 0.950237
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [210]	valid_0's ndcg@30: 0.950285
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [211]	valid_0's ndcg@30: 0.950234
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [212]	valid_0's ndcg@30: 0.95014
# [LightGBM] [Debug] Re-bagging, using 28099 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [213]	valid_0's ndcg@30: 0.949882
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 14
# [214]	valid_0's ndcg@30: 0.949913
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [215]	valid_0's ndcg@30: 0.949701
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [216]	valid_0's ndcg@30: 0.950332
# [LightGBM] [Debug] Re-bagging, using 28110 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [217]	valid_0's ndcg@30: 0.950121
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [218]	valid_0's ndcg@30: 0.950121
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 16
# [219]	valid_0's ndcg@30: 0.950092
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [220]	valid_0's ndcg@30: 0.949983
# [LightGBM] [Debug] Re-bagging, using 28014 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [221]	valid_0's ndcg@30: 0.949888
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [222]	valid_0's ndcg@30: 0.94985
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 14
# [223]	valid_0's ndcg@30: 0.95009
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [224]	valid_0's ndcg@30: 0.950316
# [LightGBM] [Debug] Re-bagging, using 28102 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 15
# [225]	valid_0's ndcg@30: 0.950441
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 16
# [226]	valid_0's ndcg@30: 0.950214
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [227]	valid_0's ndcg@30: 0.950586
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [228]	valid_0's ndcg@30: 0.950372
# [LightGBM] [Debug] Re-bagging, using 27926 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [229]	valid_0's ndcg@30: 0.950298
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [230]	valid_0's ndcg@30: 0.950094
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [231]	valid_0's ndcg@30: 0.95003
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 14
# [232]	valid_0's ndcg@30: 0.950048
# [LightGBM] [Debug] Re-bagging, using 27992 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [233]	valid_0's ndcg@30: 0.950138
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [234]	valid_0's ndcg@30: 0.950157
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [235]	valid_0's ndcg@30: 0.950136
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [236]	valid_0's ndcg@30: 0.950235
# [LightGBM] [Debug] Re-bagging, using 28074 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 15
# [237]	valid_0's ndcg@30: 0.950457
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 14
# [238]	valid_0's ndcg@30: 0.950181
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [239]	valid_0's ndcg@30: 0.950208
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [240]	valid_0's ndcg@30: 0.950436
# [LightGBM] [Debug] Re-bagging, using 27978 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [241]	valid_0's ndcg@30: 0.950432
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [242]	valid_0's ndcg@30: 0.950368
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [243]	valid_0's ndcg@30: 0.950479
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 14
# [244]	valid_0's ndcg@30: 0.950685
# [LightGBM] [Debug] Re-bagging, using 28149 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 14
# [245]	valid_0's ndcg@30: 0.950393
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [246]	valid_0's ndcg@30: 0.950118
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [247]	valid_0's ndcg@30: 0.950104
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 17
# [248]	valid_0's ndcg@30: 0.94996
# [LightGBM] [Debug] Re-bagging, using 28118 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [249]	valid_0's ndcg@30: 0.950308
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [250]	valid_0's ndcg@30: 0.950016
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [251]	valid_0's ndcg@30: 0.950103
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [252]	valid_0's ndcg@30: 0.950073
# [LightGBM] [Debug] Re-bagging, using 27886 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 14
# [253]	valid_0's ndcg@30: 0.950044
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [254]	valid_0's ndcg@30: 0.950037
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [255]	valid_0's ndcg@30: 0.950294
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 16
# [256]	valid_0's ndcg@30: 0.95028
# [LightGBM] [Debug] Re-bagging, using 27938 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [257]	valid_0's ndcg@30: 0.950084
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [258]	valid_0's ndcg@30: 0.950113
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 17
# [259]	valid_0's ndcg@30: 0.950156
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 9
# [260]	valid_0's ndcg@30: 0.950299
# [LightGBM] [Debug] Re-bagging, using 28032 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [261]	valid_0's ndcg@30: 0.950286
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [262]	valid_0's ndcg@30: 0.950518
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [263]	valid_0's ndcg@30: 0.950533
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [264]	valid_0's ndcg@30: 0.950536
# [LightGBM] [Debug] Re-bagging, using 27939 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [265]	valid_0's ndcg@30: 0.950501
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [266]	valid_0's ndcg@30: 0.950445
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [267]	valid_0's ndcg@30: 0.950394
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [268]	valid_0's ndcg@30: 0.950387
# [LightGBM] [Debug] Re-bagging, using 28080 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 9
# [269]	valid_0's ndcg@30: 0.950307
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [270]	valid_0's ndcg@30: 0.950259
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [271]	valid_0's ndcg@30: 0.95022
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [272]	valid_0's ndcg@30: 0.950215
# [LightGBM] [Debug] Re-bagging, using 28019 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [273]	valid_0's ndcg@30: 0.950236
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [274]	valid_0's ndcg@30: 0.950443
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [275]	valid_0's ndcg@30: 0.950356
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [276]	valid_0's ndcg@30: 0.950247
# [LightGBM] [Debug] Re-bagging, using 27918 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [277]	valid_0's ndcg@30: 0.950225
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [278]	valid_0's ndcg@30: 0.950273
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [279]	valid_0's ndcg@30: 0.949961
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [280]	valid_0's ndcg@30: 0.949997
# [LightGBM] [Debug] Re-bagging, using 27938 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [281]	valid_0's ndcg@30: 0.95005
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 14
# [282]	valid_0's ndcg@30: 0.950053
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [283]	valid_0's ndcg@30: 0.950159
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 16
# [284]	valid_0's ndcg@30: 0.950029
# [LightGBM] [Debug] Re-bagging, using 28092 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [285]	valid_0's ndcg@30: 0.949693
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 9
# [286]	valid_0's ndcg@30: 0.949617
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [287]	valid_0's ndcg@30: 0.949997
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 8
# [288]	valid_0's ndcg@30: 0.949839
# [LightGBM] [Debug] Re-bagging, using 27921 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 14
# [289]	valid_0's ndcg@30: 0.95028
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 15
# [290]	valid_0's ndcg@30: 0.950367
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 17
# [291]	valid_0's ndcg@30: 0.95019
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 15
# [292]	valid_0's ndcg@30: 0.950514
# [LightGBM] [Debug] Re-bagging, using 28105 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [293]	valid_0's ndcg@30: 0.950729
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [294]	valid_0's ndcg@30: 0.950584
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [295]	valid_0's ndcg@30: 0.950324
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [296]	valid_0's ndcg@30: 0.950239
# [LightGBM] [Debug] Re-bagging, using 27935 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [297]	valid_0's ndcg@30: 0.950213
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [298]	valid_0's ndcg@30: 0.949841
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [299]	valid_0's ndcg@30: 0.949984
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [300]	valid_0's ndcg@30: 0.949977
# [LightGBM] [Debug] Re-bagging, using 28091 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 9
# [301]	valid_0's ndcg@30: 0.949932
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 14
# [302]	valid_0's ndcg@30: 0.949844
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [303]	valid_0's ndcg@30: 0.950122
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [304]	valid_0's ndcg@30: 0.950158
# [LightGBM] [Debug] Re-bagging, using 28126 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [305]	valid_0's ndcg@30: 0.950177
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 15
# [306]	valid_0's ndcg@30: 0.950186
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [307]	valid_0's ndcg@30: 0.949995
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [308]	valid_0's ndcg@30: 0.949736
# [LightGBM] [Debug] Re-bagging, using 28166 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [309]	valid_0's ndcg@30: 0.949577
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [310]	valid_0's ndcg@30: 0.949574
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [311]	valid_0's ndcg@30: 0.949607
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 14
# [312]	valid_0's ndcg@30: 0.949537
# [LightGBM] [Debug] Re-bagging, using 28033 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 14
# [313]	valid_0's ndcg@30: 0.949167
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [314]	valid_0's ndcg@30: 0.949397
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [315]	valid_0's ndcg@30: 0.949358
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [316]	valid_0's ndcg@30: 0.949238
# [LightGBM] [Debug] Re-bagging, using 28169 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [317]	valid_0's ndcg@30: 0.949093
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [318]	valid_0's ndcg@30: 0.948914
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [319]	valid_0's ndcg@30: 0.948882
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [320]	valid_0's ndcg@30: 0.948896
# [LightGBM] [Debug] Re-bagging, using 28095 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [321]	valid_0's ndcg@30: 0.948986
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 20
# [322]	valid_0's ndcg@30: 0.948993
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 14
# [323]	valid_0's ndcg@30: 0.949575
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [324]	valid_0's ndcg@30: 0.949391
# [LightGBM] [Debug] Re-bagging, using 28185 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [325]	valid_0's ndcg@30: 0.949307
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 17
# [326]	valid_0's ndcg@30: 0.949793
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 14
# [327]	valid_0's ndcg@30: 0.949771
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 9
# [328]	valid_0's ndcg@30: 0.949879
# [LightGBM] [Debug] Re-bagging, using 27911 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [329]	valid_0's ndcg@30: 0.949874
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 16
# [330]	valid_0's ndcg@30: 0.950083
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 9
# [331]	valid_0's ndcg@30: 0.949918
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 16
# [332]	valid_0's ndcg@30: 0.949942
# [LightGBM] [Debug] Re-bagging, using 27948 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 15
# [333]	valid_0's ndcg@30: 0.949643
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [334]	valid_0's ndcg@30: 0.950031
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 16
# [335]	valid_0's ndcg@30: 0.950216
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 16
# [336]	valid_0's ndcg@30: 0.950213
# [LightGBM] [Debug] Re-bagging, using 27966 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 17
# [337]	valid_0's ndcg@30: 0.95022
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [338]	valid_0's ndcg@30: 0.95023
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 16
# [339]	valid_0's ndcg@30: 0.949735
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 14
# [340]	valid_0's ndcg@30: 0.949608
# [LightGBM] [Debug] Re-bagging, using 28116 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [341]	valid_0's ndcg@30: 0.949802
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [342]	valid_0's ndcg@30: 0.949838
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [343]	valid_0's ndcg@30: 0.949999
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 15
# [344]	valid_0's ndcg@30: 0.949865
# [LightGBM] [Debug] Re-bagging, using 28032 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [345]	valid_0's ndcg@30: 0.95018
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [346]	valid_0's ndcg@30: 0.95016
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [347]	valid_0's ndcg@30: 0.950159
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [348]	valid_0's ndcg@30: 0.950206
# [LightGBM] [Debug] Re-bagging, using 28082 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 14
# [349]	valid_0's ndcg@30: 0.950062
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [350]	valid_0's ndcg@30: 0.950052
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 19
# [351]	valid_0's ndcg@30: 0.949439
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [352]	valid_0's ndcg@30: 0.949539
# [LightGBM] [Debug] Re-bagging, using 27853 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [353]	valid_0's ndcg@30: 0.949713
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [354]	valid_0's ndcg@30: 0.949795
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 15
# [355]	valid_0's ndcg@30: 0.949946
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [356]	valid_0's ndcg@30: 0.949643
# [LightGBM] [Debug] Re-bagging, using 28229 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 14
# [357]	valid_0's ndcg@30: 0.949807
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [358]	valid_0's ndcg@30: 0.949225
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 15
# [359]	valid_0's ndcg@30: 0.949147
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 14
# [360]	valid_0's ndcg@30: 0.949143
# [LightGBM] [Debug] Re-bagging, using 28132 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 16
# [361]	valid_0's ndcg@30: 0.949287
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [362]	valid_0's ndcg@30: 0.949293
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 9
# [363]	valid_0's ndcg@30: 0.949115
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [364]	valid_0's ndcg@30: 0.949082
# [LightGBM] [Debug] Re-bagging, using 28095 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [365]	valid_0's ndcg@30: 0.949175
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [366]	valid_0's ndcg@30: 0.949066
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [367]	valid_0's ndcg@30: 0.949751
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [368]	valid_0's ndcg@30: 0.949666
# [LightGBM] [Debug] Re-bagging, using 28047 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [369]	valid_0's ndcg@30: 0.949696
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [370]	valid_0's ndcg@30: 0.949687
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [371]	valid_0's ndcg@30: 0.949612
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [372]	valid_0's ndcg@30: 0.949404
# [LightGBM] [Debug] Re-bagging, using 28194 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [373]	valid_0's ndcg@30: 0.949721
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 14
# [374]	valid_0's ndcg@30: 0.949647
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [375]	valid_0's ndcg@30: 0.949647
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [376]	valid_0's ndcg@30: 0.949555
# [LightGBM] [Debug] Re-bagging, using 28168 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [377]	valid_0's ndcg@30: 0.949862
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [378]	valid_0's ndcg@30: 0.949759
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [379]	valid_0's ndcg@30: 0.949743
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 14
# [380]	valid_0's ndcg@30: 0.949543
# [LightGBM] [Debug] Re-bagging, using 28036 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [381]	valid_0's ndcg@30: 0.949578
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 9
# [382]	valid_0's ndcg@30: 0.949495
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 16
# [383]	valid_0's ndcg@30: 0.949467
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [384]	valid_0's ndcg@30: 0.94973
# [LightGBM] [Debug] Re-bagging, using 27970 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 15
# [385]	valid_0's ndcg@30: 0.949914
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 15
# [386]	valid_0's ndcg@30: 0.949707
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [387]	valid_0's ndcg@30: 0.949723
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [388]	valid_0's ndcg@30: 0.949654
# [LightGBM] [Debug] Re-bagging, using 27732 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [389]	valid_0's ndcg@30: 0.949787
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 13
# [390]	valid_0's ndcg@30: 0.949646
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 17
# [391]	valid_0's ndcg@30: 0.949296
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 15
# [392]	valid_0's ndcg@30: 0.949292
# [LightGBM] [Debug] Re-bagging, using 27991 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 16
# [393]	valid_0's ndcg@30: 0.949352
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 20
# [394]	valid_0's ndcg@30: 0.949674
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [395]	valid_0's ndcg@30: 0.950006
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [396]	valid_0's ndcg@30: 0.949921
# [LightGBM] [Debug] Re-bagging, using 28151 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 11
# [397]	valid_0's ndcg@30: 0.949804
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 12
# [398]	valid_0's ndcg@30: 0.950166
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 10
# [399]	valid_0's ndcg@30: 0.950246
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 9
# [400]	valid_0's ndcg@30: 0.950303

# %% [markdown]
# 最后，我们可以在测试集上进行检验，并显示特征重要度。

# %%
import collections
import os
import sys

def predict(x_test, comments, model_input_path):
    '''
    预测得分并排序
    '''
    gbm = lgb.Booster(model_file=model_input_path)  # 加载model

    ypred = gbm.predict(x_test)

    predicted_sorted_indexes = np.argsort(ypred)[::-1]  # 返回从大到小的索引

    t_results = comments[predicted_sorted_indexes]  # 返回对应的comments,从大到小的排序

    return t_results

def validate(qids, targets, preds, k):
    """
    qids:数据里的QueryID
    targets:目标值，真实值
    preds:预测值
    k: ndcg@k 里的k
    """
    query_groups = get_groups(qids)  # (qid,from,to),一个元组,表示这个qid的样本从哪到哪
    all_ndcg = []
    every_qid_ndcg = collections.OrderedDict()

    for qid, a, b in query_groups:
        predicted_sorted_indexes = np.argsort(preds[a:b])[::-1] # 从大到小的索引
        t_results = targets[a:b] # 目标数据的相关度
        t_results = t_results[predicted_sorted_indexes] #是predicted_sorted_indexes排好序的在test_data中的相关度
        dcg_val = dcg_k(t_results, k)
        idcg_val = ideal_dcg_k(t_results, k)
        ndcg_val = (dcg_val / idcg_val)
        all_ndcg.append(ndcg_val)
        every_qid_ndcg.setdefault(qid, ndcg_val)

    average_ndcg = np.nanmean(all_ndcg)
    return average_ndcg, every_qid_ndcg

def get_groups(qids):
    """Makes an iterator of query groups on the provided list of query ids.

    Parameters
    ----------
    qids : array_like of shape = [n_samples]
        List of query ids.

    Yields
    ------
    row : (qid, int, int)
        Tuple of query id, from, to.
        ``[i for i, q in enumerate(qids) if q == qid] == range(from, to)``
    """
    prev_qid = None
    prev_limit = 0
    total = 0

    for i, qid in enumerate(qids):
        total += 1
        if qid != prev_qid:
            if i != prev_limit:
                yield (prev_qid, prev_limit, i)
            prev_qid = qid
            prev_limit = i

    if prev_limit != total:
        yield (prev_qid, prev_limit, total)

def group_queries(training_data, qid_index):
    """
        Returns a dictionary that groups the documents by their query ids.
        Parameters
        ----------
        training_data : Numpy array of lists
            Contains a list of document information. Each document's format is [relevance score, query index, feature vector]
        qid_index : int
            This is the index where the qid is located in the training data

        Returns
        -------
        query_indexes : dictionary
            The keys were the different query ids and teh values were the indexes in the training data that are associated of those keys.
    """
    query_indexes = {}  # 每个qid对应的样本索引范围,比如qid=1020,那么此qid在training data中的训练样本从0到100的范围, { key=str,value=[] }
    index = 0
    for record in training_data:
        query_indexes.setdefault(record[qid_index], [])
        query_indexes[record[qid_index]].append(index)
        index += 1
    return query_indexes


def dcg_k(scores, k):
    """
        Returns the DCG value of the list of scores and truncates to k values.
        Parameters
        ----------
        scores : list
            Contains labels in a certain ranked order
        k : int
            In the amount of values you want to only look at for computing DCG

        Returns
        -------
        DCG_val: int
            This is the value of the DCG on the given scores
    """
    return np.sum([
                      (np.power(2, scores[i]) - 1) / np.log2(i + 2)
                      for i in range(len(scores[:k]))
                      ])


def ideal_dcg_k(scores, k):
    """
    前k个理想状态下的dcg
        Returns the Ideal DCG value of the list of scores and truncates to k values.
        Parameters
        ----------
        scores : list
            Contains labels in a certain ranked order
        k : int
            In the amount of values you want to only look at for computing DCG

        Returns
        -------
        Ideal_DCG_val: int
            This is the value of the Ideal DCG on the given scores
    """
    # 相关度降序排序
    scores = [score for score in sorted(scores)[::-1]]
    return dcg_k(scores, k)

def plot_print_feature_importance(model_path):
    '''
    打印特征的重要度
    '''
    #模型中的特征是Column_数字,这里打印重要度时可以映射到真实的特征名

    if not os.path.exists(model_path):
        print("file no exists! {}".format(model_path))
        sys.exit(0)

    gbm = lgb.Booster(model_file=model_path)

    # 打印和保存特征重要度
    importances = gbm.feature_importance(importance_type='split')
    feature_names = gbm.feature_name()

    sum = 0.
    for value in importances:
        sum += value

    importance_data = []
    head = ['特征','重要度','重要度比例']

    for feature_name, importance in zip(feature_names, importances):
        # feat_id = int(feature_name.split('_')[1]) + 1
        print(' {} : {} : {}'.format(feature_name, importance, importance / sum))
        row = [feature_name,importance,importance/sum]
        importance_data.append(row)

    dff = pd.DataFrame(importance_data,columns=head)
    dff.to_csv('./importance.csv',index=False)

# 预测
gbm = lgb.Booster(model_file='./model/model.txt')
test_predict = gbm.predict(test_X)
average_ndcg, _ = validate(test_qid, test_y, test_predict, 10)

# 所有qid的平均ndcg
print("all qid average ndcg@10: ", average_ndcg)

# 保存特征重要度
plot_print_feature_importance('./model/model.txt')
# Out:
# [LightGBM] [Debug] Skipped header "tree" in file ./model/model.txt
# [LightGBM] [Debug] Skipped header "tree" in file ./model/model.txt
# [LightGBM] [Debug] Time for loading model: 0.040929 seconds
# all qid average ndcg@10:  0.923663279115351

# %% [markdown]
# 最终我们的模型在测试集上的ndcg@10约为0.9237，效果不错。
#
# ### 四、PC端的制作
# 模型终归是模型，要想让用户使用，就必须做出可视化界面。目前我们和kkdy
# 合作一起开发网页版和小程序，这几天寒假闲着没事，我自己自学了pyqt
# 做了个桌面程序，实现了box推荐的功能。源代码已经放在了我的Github里~
#
# ### 五、总结
#
# 费时半年的项目，终于做完了！个人感觉用AI做这个罗德岛之心Box推荐系统并不是非常困难。
# 实际上，罗德岛之心的这个模式可以同样套用在其他手游上，不过本人精力有限，就只做方舟的了。
#
# 此外，这套干员推荐系统，稍作修改的话或许也可以用在肉鸽活动上，感觉可以一搞，不过现在思路还没完全确定，先等下一次肉鸽活动再说吧。
#
# 如果你喜欢我的项目的话，还请到我的Github里点一颗星，谢谢各位了~
#
# 参考资料：
#
# 1.机器学习排序算法：RankNet to LambdaRank to LambdaMART: https://www.cnblogs.com/genyuan/p/9788294.html
#
# 2.利用lightGBM做LTR排序： https://github.com/jiangnanboy/learning_to_rank
#
# 3.策略算法工程师之路-排序模型(LTR)及应用： https://zhuanlan.zhihu.com/p/113302654
